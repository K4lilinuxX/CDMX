# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("viajes_ecobici_cdmx.csv")

# %%
df
# Out:
#        anio      mes       fecha  genero  viajes
# 0      2024    Marzo  2024-03-01  Hombre   49036
# 1      2024    Marzo  2024-03-01   Mujer   20220
# 2      2024    Marzo  2024-03-01    Otro    1438
# 3      2024    Marzo  2024-03-02  Hombre   29297
# 4      2024    Marzo  2024-03-02   Mujer   12926
# ...     ...      ...         ...     ...     ...
# 12256  2024  Febrero  2024-02-28   Mujer   20284
# 12257  2024  Febrero  2024-02-28    Otro    1377
# 12258  2024  Febrero  2024-02-29  Hombre   50109
# 12259  2024  Febrero  2024-02-29   Mujer   20091
# 12260  2024  Febrero  2024-02-29    Otro    1357
#
# [12261 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   anio    12261 non-null  int64
#  1   mes     12261 non-null  str
#  2   fecha   12261 non-null  str
#  3   genero  11278 non-null  str
#  4   viajes  12261 non-null  int64
# dtypes: int64(2), str(3)
# memory usage: 479.1 KB

# %%
# ¿Hay datos nulos?
df.isna().sum()
# Out:
# anio        0
# mes         0
# fecha       0
# genero    983
# viajes      0
# dtype: int64

# %%
# Dimensiones del Data Frame
print(f"El Data Frame tiene {df.shape[0]:,.0f} filas")
print(f"El Data Frame tiene {df.shape[1]} columnas")
# Out:
# El Data Frame tiene 12,261 filas
# El Data Frame tiene 5 columnas
